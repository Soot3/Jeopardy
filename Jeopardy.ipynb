# %% [markdown]
# ## Patterns in Jeopardy! Questions

# %% [markdown]
# Jeopardy the Tv Show has people come up to answer questions based on a variety of topics for cash prizes. This project looks into any patterns in the questions and the best methods to win.
# Dataset gotten from [here](https://www.reddit.com/r/datasets/comments/1uyd0t/200000_jeopardy_questions_in_a_json_file)

# %%
import pandas as pd

jeo_data = pd.read_csv('jeopardy.csv', parse_dates=[' Air Date'])

# %%
jeo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 7 columns):
# Show Number    19999 non-null int64
#  Air Date      19999 non-null datetime64[ns]
#  Round         19999 non-null object
#  Category      19999 non-null object
#  Value         19999 non-null object
#  Question      19999 non-null object
#  Answer        19999 non-null object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 1.1+ MB

# %%
jeo_data.head()
# Out:
#    Show Number   Air Date      Round                         Category  Value  \
# 0         4680 2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680 2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeo_data.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
jeo_data.columns = jeo_data.columns.str.strip()

# %%
jeo_data.columns
# Out:
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %%
import re
def norm_string(text):
    text = text.lower()
    text = re.sub("[^A-Za-z0-9\s]", "", text)
    text = re.sub("\s+", " ", text)
    return text

# %%
jeo_data['clean_question'] = jeo_data['Question'].apply(norm_string)
jeo_data['clean_answer'] = jeo_data['Answer'].apply(norm_string)

# %%
j = ['Question', 'clean_question', 'Answer', 'clean_answer']
jeo_data[j].head(10)
# Out:
#                                             Question  \
# 0  For the last 8 years of his life, Galileo was ...
# 1  No. 2: 1912 Olympian; football star at Carlisl...
# 2  The city of Yuma in this state has a record av...
# 3  In 1963, live on "The Art Linkletter Show", th...
# 4  Signer of the Dec. of Indep., framer of the Co...
# 5  In the title of an Aesop fable, this insect sh...
# 6  Built in 312 B.C. to link Rome & the South of ...
# 7  No. 8: 30 steals for the Birmingham Barons; 2,...
# 8  In the winter of 1971-72, a record 1,122 inche...
# 9  This housewares store was named for the packag...
#
#                                       clean_question          Answer  \
# 0  for the last 8 years of his life galileo was u...      Copernicus
# 1  no 2 1912 olympian football star at carlisle i...      Jim Thorpe
# 2  the city of yuma in this state has a record av...         Arizona
# 3  in 1963 live on the art linkletter show this c...      McDonald's
# 4  signer of the dec of indep framer of the const...      John Adams
# 5  in the title of an aesop fable this insect sha...         the ant
# 6  built in 312 bc to link rome the south of ital...  the Appian Way
# 7  no 8 30 steals for the birmingham barons 2306 ...  Michael Jordan
# 8  in the winter of 197172 a record 1122 inches o...      Washington
# 9  this housewares store was named for the packag...  Crate & Barrel
#
#      clean_answer
# 0      copernicus
# 1      jim thorpe
# 2         arizona
# 3       mcdonalds
# 4      john adams
# 5         the ant
# 6  the appian way
# 7  michael jordan
# 8      washington
# 9    crate barrel

# %%
def norm_val(value):
    value = re.sub("[^A-Za-z0-9\s]", "", value)
    try:
        value = int(value)
    except Exception:
        value = 0
    return value

# %%
jeo_data['clean_value'] = jeo_data['Value'].apply(norm_val)

# %%
j = ['Value', 'clean_value']
jeo_data[j].head()
# Out:
#   Value  clean_value
# 0  $200          200
# 1  $200          200
# 2  $200          200
# 3  $200          200
# 4  $200          200

# %% [markdown]
# ## How often the answer is deducible from the question.

# %%
def count_matches(row):
    split_answer = row["clean_answer"].split()
    split_question = row["clean_question"].split()
    if "the" in split_answer:
        split_answer.remove("the")
    if len(split_answer) == 0:
        return 0
    match_count = 0
    for item in split_answer:
        if item in split_question:
            match_count += 1
    return match_count / len(split_answer)

jeo_data["answer_in_question"] = jeo_data.apply(count_matches, axis=1)

# %%
jeo_data['answer_in_question'].mean()
# Out:
# 0.05900196524977763

# %%
mean_df = jeo_data[jeo_data["answer_in_question"] >= 0.6]
mean_df[['Category','Question','clean_answer','answer_in_question']]
# Out:
#                              Category  \
# 232                            ANGELS
# 266    NOT A CURRENT NATIONAL CAPITAL
# 272    NOT A CURRENT NATIONAL CAPITAL
# 278    NOT A CURRENT NATIONAL CAPITAL
# 284    NOT A CURRENT NATIONAL CAPITAL
# 290    NOT A CURRENT NATIONAL CAPITAL
# 395                       WORLD FACTS
# 661         SHAKESPEAREAN LAST SCENES
# 677                        VERMONTERS
# 815                         THE 1890s
# 826                       PLAYWRIGHTS
# 1092                     CENTRAL PARK
# 1137                          PEANUTS
# 1144                  THE MIDDLE AGES
# 1150                  THE MIDDLE AGES
# 1459        HIDDEN BOOKS OF THE BIBLE
# 1465        HIDDEN BOOKS OF THE BIBLE
# 1471        HIDDEN BOOKS OF THE BIBLE
# 1477        HIDDEN BOOKS OF THE BIBLE
# 1483        HIDDEN BOOKS OF THE BIBLE
# 1552              WHAT ARE YOU DOING?
# 1576              WHAT ARE YOU DOING?
# 1840                     TAKE A GUESS
# 2051                            MISC.
# 2097            YOUR HONOR, I OBJECT!
# 2347                     BIRD HUNTING
# 2512                CHECK OUT MY CRIB
# 2572                THE PLANET URANUS
# 2818                   STUPID ANSWERS
# 2828                   STUPID ANSWERS
# ...                               ...
# 17078              THAT'S NOT KOSHER!
# 17426                NAUGHT'S LANDING
# 17533                    MEALTIME LIT
# 17715         GETTING CONFRONTATIONAL
# 17795                     THAT'S RARE
# 17978                       LOUISIANA
# 18058                PUT 'EM IN ORDER
# 18064                PUT 'EM IN ORDER
# 18069                PUT 'EM IN ORDER
# 18074                PUT 'EM IN ORDER
# 18078                PUT 'EM IN ORDER
# 18114                      DORM DECOR
# 18120                      DORM DECOR
# 18184                         SCIENCE
# 18213                     SILLY SONGS
# 18367                  SIMPLE SCIENCE
# 18560       WHICH TV SHOW CAME FIRST?
# 18566       WHICH TV SHOW CAME FIRST?
# 18572       WHICH TV SHOW CAME FIRST?
# 18578       WHICH TV SHOW CAME FIRST?
# 18584       WHICH TV SHOW CAME FIRST?
# 19262            THE DEAD SEA SCROLLS
# 19375                     JOB HUNTING
# 19421                      UPHOLSTERY
# 19441                     JUST SAY NO
# 19511                  STUPID ANSWERS
# 19626           WHAT'S THE NEXT LINE?
# 19644           WHAT'S THE NEXT LINE?
# 19860                 THE WEST INDIES
# 19994                  U.S. GEOGRAPHY
#
#                                                 Question  \
# 232    With an appropriate-sounding name, John Dye pl...
# 266                     Ljubljana, Bratislava, Barcelona
# 272                              Istanbul, Ottawa, Amman
# 278                              Sofia, Sarajevo, Saigon
# 284                                Bucharest, Bonn, Bern
# 290             Belize City, Guatemala City, Panama City
# 395    A humid city, Rio de Janeiro lies just north o...
# 661    You could say this comedy "ends well" -- Helen...
# 677    George Franklin Edmunds wrote most of this ant...
# 815    Of "Frankenstein", "The Invisible Man" or "Dra...
# 826    These British twin brother playwrights wrote m...
# 1092   Cleopatra's Needle is a short walk from this E...
# 1137   Of a 25th, 30th or 40th anniversary, what "Pea...
# 1144   2 types of these which were especially popular...
# 1150   This famous "song" is a romanticized account o...
# 1459   Sending money was the best her friends could d...
# 1465       Fight the evil mojo by using your good voodoo
# 1471   Top chefs know that Pez rarely makes it onto t...
# 1477   For hungry sandwich lovers, jam ostensibly mak...
# 1483       From answers to questions; that's "Jeopardy!"
# 1552   Making one of these with a few people; a frame...
# 1576   Giving a room visual interest with this trim a...
# 1840   Of a pogo stick injury, a dense winter fog or ...
# 2051   Jules Verne's book "Around the Moon" was the s...
# 2097   Calls for an opinion--only allowed for this ty...
# 2347   The third rail in a subway system is the one w...
# 2512   Sit down in this chair with an X-shaped frame ...
# 2572   Of 84, 184 or 284, the length in years of one ...
# 2818   In 1842, Richard Owen coined this word for “di...
# 2828   While Bugs was “introduced” in “Porky’s Hare H...
# ...                                                  ...
# 17078  Of chicken cacciatore, veal parmigiana or fett...
# 17426  The title of the Gary Oldman movie this 'by Mo...
# 17533  Anne Tyler sported a full menu when she wrote ...
# 17715  A split in the Plantagenet family led to this ...
# 17795  Except to break ties, this presiding officer o...
# 17978  In production of cotton, minerals & natural ga...
# 18058  "Revolver",  "Sgt. Pepper's Lonely Hearts Club...
# 18064         Calamity Jane, Jane Curtin, Lady Jane Grey
# 18069      William Baldwin, Daniel Baldwin, Alec Baldwin
# 18074            Ramses II, Nebuchadnezzar, King Solomon
# 18078  Oklahoma statehood, Hawaii statehood, Arizona ...
# 18114  Make a statement about the infantilization of ...
# 18120  You can find a floral bedding ensemble from th...
# 18184  This type of "cell" sounds like it causes dise...
# 18213  Of "De Do Do Do, De Da Da Da", "Goo Goo", & "N...
# 18367  Of a proton, neutron or electron, the one that...
# 18560         "The Twilight Zone", "Twin Peaks", "20/20"
# 18566  "The Drew Carey Show", "The Bob Newhart Show",...
# 18572                        "Reba", "Seinfeld", "Maude"
# 18578  "Saturday Night Live", "Monday Night Football"...
# 18584                    "CSI: NY", "CSI: Miami", "NCIS"
# 19262  The Scrolls reveal a rich & diversified litera...
# 19375  In a 60-year-old man age really takes its toll...
# 19421  Often, only the feet are left uncovered in a c...
# 19441  In Morse code, beginning with dash dot & endin...
# 19511              It's the third-largest city in Kansas
# 19626                  "Oh my darling, oh my darling..."
# 19644                        "Yes we have no bananas..."
# 19860  Once known as St. Christopher and Nevis, it's ...
# 19994  Of 8, 12 or 18, the number of U.S. states that...
#
#                                             clean_answer  answer_in_question
# 232                                       angel of death            0.666667
# 266                                            barcelona            1.000000
# 272                                             istanbul            1.000000
# 278                                               saigon            1.000000
# 284                                                 bonn            1.000000
# 290                                          belize city            1.000000
# 395                              the tropic of capricorn            0.666667
# 661                             alls well that ends well            0.600000
# 677                            the sherman antitrust act            0.666667
# 815                         frankenstein created in 1818            0.750000
# 826                                peter anthony shaffer            0.666667
# 1092                                the temple of dendur            0.666667
# 1137                                    40th anniversary            1.000000
# 1144                                      types of plays            0.666667
# 1150                                      song of roland            0.666667
# 1459                                     esther best her            0.666667
# 1465                                         job mojo by            0.666667
# 1471                                     ezra pez rarely            0.666667
# 1477                                 amos jam ostensibly            0.666667
# 1483                                 romans from answers            0.666667
# 1552                                      making a quilt            0.666667
# 1576                                        a chair rail            0.666667
# 1840                                  a dense winter fog            1.000000
# 2051                          from the earth to the moon            0.600000
# 2097                                   an expert witness            0.666667
# 2347                                              a rail            1.000000
# 2512                                   a directors chair            0.666667
# 2572                                                  84            1.000000
# 2818                                            dinosaur            1.000000
# 2828                                    porkys duck hunt            0.666667
# ...                                                  ...                 ...
# 17078                                    veal parmigiana            1.000000
# 17426                                       nil by mouth            0.666667
# 17533                  dinner at the homesick restaurant            0.750000
# 17715                              the wars of the roses            0.750000
# 17795                           the speaker of the house            0.750000
# 17978                                             cotton            1.000000
# 18058  meet the beatles revolver sgt peppers lonely h...            1.000000
# 18064           lady jane grey calamity jane jane curtin            1.000000
# 18069                                alec daniel william            1.000000
# 18074              ramses ii king solomon nebuchadnezzar            1.000000
# 18078                            oklahoma arizona hawaii            1.000000
# 18114                                    a beanbag chair            0.666667
# 18120                                    linens n things            0.666667
# 18184                                        a germ cell            0.666667
# 18213                                            goo goo            1.000000
# 18367                                            neutron            1.000000
# 18560                                  the twilight zone            1.000000
# 18566                               the bob newhart show            1.000000
# 18572                                              maude            1.000000
# 18578                              monday night football            1.000000
# 18584                                          csi miami            1.000000
# 19262                           the second temple period            0.666667
# 19375                          manager in man age really            0.800000
# 19421                               an overstuffed chair            0.666667
# 19441                                     dash dash dash            1.000000
# 19511                                        kansas city            1.000000
# 19626                           oh my darling clementine            0.750000
# 19644                           we have no bananas today            0.800000
# 19860                                 st kitts and nevis            0.750000
# 19994                                                 18            1.000000
#
# [257 rows x 4 columns]

# %% [markdown]
# As we can see a number of questions that have their answers in them are questions that require choosing an option from a list of options.

# %% [markdown]
# ## How often new questions are repeats of older questions?

# %%
question_overlap = []
terms_used = set()
jeo_data.sort_values(['Air Date'], ascending=True, inplace=True)
match_count = 0
for index, row in jeo_data.iterrows():
    split_question = row['clean_question'].split()
    for value in split_question:
        if len(value) < 6:
            split_question.remove(value)
            continue
        if value in terms_used:
            match_count += 1
        else:
            terms_used.add(value)
    if len(split_question) > 0:
        match_count /= len(split_question)
    question_overlap.append(match_count)

jeo_data['question_overlap'] = question_overlap
print(jeo_data['question_overlap'].mean())
# Out:
# 0.23690079733126823

# %% [markdown]
# About 23% percent of the questions in this dataset have been repeated previously. So the odds of winning can be increased a bit this way

# %% [markdown]
# ## Investigating relationships between Questions and Value

# %% [markdown]
# We are doing this to investigate if there are some words in the answer who tend to be more related to high value questions rather than to low values ones - that is, a relationship between categorical variables.

# %%
def determine_value(row):
    value = 0
    if row["clean_value"] > 800:
        value = 1
    return value

jeo_data["high_value"] = jeo_data.apply(determine_value, axis=1)

def count_usage(term):
    low_count = 0
    high_count = 0
    for i, row in jeo_data.iterrows():
        if term in row["clean_question"].split(" "):
            if row["high_value"] == 1:
                high_count += 1
            else:
                low_count += 1
    return high_count, low_count

# %%
from random import choice

terms_used_list = list(terms_used)
comparison_terms = [choice(terms_used_list) for _ in range(10)]

observed_expected = []

for term in comparison_terms:
    observed_expected.append(count_usage(term))

observed_expected
# Out:
# [(0, 1),
#  (1, 1),
#  (0, 1),
#  (0, 2),
#  (0, 1),
#  (2, 2),
#  (0, 2),
#  (1, 3),
#  (0, 1),
#  (1, 2)]

# %%
from scipy.stats import chisquare
import numpy as np

high_value_count = jeo_data[jeo_data["high_value"] == 1].shape[0]
low_value_count = jeo_data[jeo_data["high_value"] == 0].shape[0]

chi_squared = []
for obs in observed_expected:
    total = sum(obs)
    total_prop = total / jeo_data.shape[0]
    high_value_exp = total_prop * high_value_count
    low_value_exp = total_prop * low_value_count
    
    observed = np.array([obs[0], obs[1]])
    expected = np.array([high_value_exp, low_value_exp])
    chi_squared.append(chisquare(observed, expected))

chi_squared
# Out:
# [Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.4448774816612795, pvalue=0.5047776487545996),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.803925692253768, pvalue=0.3699222378079571),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.889754963322559, pvalue=0.3455437191483468),
#  Power_divergenceResult(statistic=0.803925692253768, pvalue=0.3699222378079571),
#  Power_divergenceResult(statistic=0.02636443308440769, pvalue=0.871013484688921),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.03188116723440362, pvalue=0.8582887163235293)]

# %% [markdown]
# ## Chi-squared results
#
# None of the terms had a significant difference in usage between high value and low value rows. Additionally, the frequencies were all lower than 5, so the chi-squared test isn't as valid. It would be better to run this test with only terms that have higher frequencies.
